# %%
import pandas as pd
from pandas.plotting import scatter_matrix
# from matplotlib import pyplot

from keras.models import Sequential
from keras.layers import *

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_absolute_error

from sklearn import model_selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %%
# Load training data set from CSV file
training_data_df = pd.read_csv('DataWrangling/ML_training.csv', index_col=0, na_values=[' ']).fillna(0)

# Load testing data set from CSV file
test_data_df = pd.read_csv('DataWrangling/ML_testing.csv', index_col=0, na_values=[' ']).fillna(0)


# Convert object to 0 and 1
cols = ['Cough', 'Fever', 'Active.Breathing.Shortness', 'Weight.Loss', 'Haemoptysis', 'TB.Medication.History']
training_data_df[cols] = training_data_df[cols].replace({'Yes':1, 'No': 0})
test_data_df[cols] = test_data_df[cols].replace({'Yes':1, 'No': 0})

# Convert Female to -, male to 1
training_data_df['Gender'] = training_data_df['Gender'].replace({'F': '0', 'M': '1'})
test_data_df['Gender'] = test_data_df['Gender'].replace({'F': '0', 'M': '1'})

training_data_df.info()
test_data_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18853 entries, 201141200106-2 to 203150600208-1
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Gender                      18853 non-null  object
#  1   Age                         18853 non-null  int64
#  2   Cough                       18853 non-null  int64
#  3   Fever                       18853 non-null  int64
#  4   Active.Breathing.Shortness  18853 non-null  int64
#  5   Weight.Loss                 18853 non-null  int64
#  6   Haemoptysis                 18853 non-null  int64
#  7   TB.Medication.History       18853 non-null  int64
#  8   qXRv2                       18853 non-null  float64
#  9   CAD4TB6                     18853 non-null  int64
#  10  JF1                         18853 non-null  float64
#  11  IF2                         18853 non-null  float64
#  12  Xpert2Outcome_num           18853 non-null  int64
# dtypes: float64(3), int64(9), object(1)
# memory usage: 2.0+ MB
#                Gender  Age  Cough  Fever  Active.Breathing.Shortness  \
# PID_OMRS
# 201140600008-8      0   32      0      0                           0
# 201140600021-1      1   44      1      1                           1
# 201140600027-8      1   26      1      1                           0
# 201140600082-3      1   39      1      1                           0
# 201140600030-2      0   59      1      1                           0
#
#                 Weight.Loss  Haemoptysis  TB.Medication.History     qXRv2  \
# PID_OMRS
# 201140600008-8            1            0                      0  0.368823
# 201140600021-1            1            0                      1  0.950277
# 201140600027-8            1            0                      0  0.131479
# 201140600082-3            1            0                      0  0.061645
# 201140600030-2            1            0                      1  0.840019
#
#                 CAD4TB6      JF1       IF2  Xpert2Outcome_num
# PID_OMRS
# 201140600008-8       59  0.99778  0.758563                  0
# 201140600021-1       77  0.99987  0.845887                  1
# 201140600027-8       44  0.00407  0.103325                  0
# 201140600082-3       35  0.01370  0.166080                  0
# 201140600030-2       75  0.99829  0.695038                  0

# %% [markdown]
# # Data needs to be scaled to a small range like 0 to 1 for the neural network to work well.

# %%
scaler = MinMaxScaler(feature_range=(0, 1))

# Scale both the training inputs and outputs
scaled_training = scaler.fit_transform(training_data_df)
scaled_testing = scaler.transform(test_data_df)

# Print out the adjustment that the scaler applied to the total_earnings column of data
print("Note: total_earnings values were scaled by multiplying by {:.10f} and adding {:.6f}".format(scaler.scale_[8], scaler.min_[8]))

# Create new pandas DataFrame objects from the scaled data
scaled_training_df = pd.DataFrame(scaled_training, columns=training_data_df.columns.values)
scaled_testing_df = pd.DataFrame(scaled_testing, columns=test_data_df.columns.values)

# Save scaled data dataframes to new CSV files
scaled_training_df.to_csv("DataWrangling/training_scaled.csv", index=False)
scaled_testing_df.to_csv("DataWrangling/testing_scaled.csv", index=False)
# Out:
# Note: total_earnings values were scaled by multiplying by 1.0398469453 and adding -0.021729

# %%
training_data_df = pd.read_csv("DataWrangling/training_scaled.csv")

X = training_data_df.drop(['Xpert2Outcome_num', 'IF2', 'JF1', 'CAD4TB6'], axis=1).values
Y = training_data_df[['Xpert2Outcome_num']].values
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [1.]
#  [0.]
#  [0.]]

# %% [markdown]
# # Define the model

# %%
# Define the model
model = Sequential()
model.add(Dense(9, input_dim=9, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# model.compile(loss='mean_squared_error', optimizer='adam')
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(
    X,
    Y,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
#  - 1s - loss: 0.3351 - accuracy: 0.8587
# Epoch 2/100
#  - 1s - loss: 0.2940 - accuracy: 0.8704
# Epoch 3/100
#  - 1s - loss: 0.2912 - accuracy: 0.8707
# Epoch 4/100
#  - 1s - loss: 0.2885 - accuracy: 0.8716
# Epoch 5/100
#  - 1s - loss: 0.2881 - accuracy: 0.8725
# Epoch 6/100
#  - 1s - loss: 0.2873 - accuracy: 0.8733
# Epoch 7/100
#  - 1s - loss: 0.2859 - accuracy: 0.8741
# Epoch 8/100
#  - 1s - loss: 0.2854 - accuracy: 0.8755
# Epoch 9/100
#  - 1s - loss: 0.2850 - accuracy: 0.8738
# Epoch 10/100
#  - 1s - loss: 0.2838 - accuracy: 0.8735
# Epoch 11/100
#  - 1s - loss: 0.2853 - accuracy: 0.8735
# Epoch 12/100
#  - 1s - loss: 0.2825 - accuracy: 0.8767
# Epoch 13/100
#  - 1s - loss: 0.2827 - accuracy: 0.8760
# Epoch 14/100
#  - 1s - loss: 0.2826 - accuracy: 0.8757
# Epoch 15/100
#  - 1s - loss: 0.2810 - accuracy: 0.8774
# Epoch 16/100
#  - 1s - loss: 0.2816 - accuracy: 0.8766
# Epoch 17/100
#  - 1s - loss: 0.2818 - accuracy: 0.8762
# Epoch 18/100
#  - 1s - loss: 0.2815 - accuracy: 0.8775
# Epoch 19/100
#  - 1s - loss: 0.2803 - accuracy: 0.8779
# Epoch 20/100
#  - 1s - loss: 0.2807 - accuracy: 0.8772
# Epoch 21/100
#  - 1s - loss: 0.2796 - accuracy: 0.8784
# Epoch 22/100
#  - 1s - loss: 0.2798 - accuracy: 0.8780
# Epoch 23/100
#  - 1s - loss: 0.2802 - accuracy: 0.8762
# Epoch 24/100
#  - 1s - loss: 0.2797 - accuracy: 0.8772
# Epoch 25/100
#  - 1s - loss: 0.2790 - accuracy: 0.8776
# Epoch 26/100
#  - 1s - loss: 0.2793 - accuracy: 0.8774
# Epoch 27/100
#  - 1s - loss: 0.2784 - accuracy: 0.8784
# Epoch 28/100
#  - 1s - loss: 0.2783 - accuracy: 0.8780
# Epoch 29/100
#  - 1s - loss: 0.2783 - accuracy: 0.8785
# Epoch 30/100
#  - 1s - loss: 0.2780 - accuracy: 0.8763
# Epoch 31/100
#  - 1s - loss: 0.2779 - accuracy: 0.8775
# Epoch 32/100
#  - 1s - loss: 0.2777 - accuracy: 0.8778
# Epoch 33/100
#  - 1s - loss: 0.2773 - accuracy: 0.8773
# Epoch 34/100
#  - 1s - loss: 0.2778 - accuracy: 0.8787
# Epoch 35/100
#  - 1s - loss: 0.2767 - accuracy: 0.8777
# Epoch 36/100
#  - 1s - loss: 0.2771 - accuracy: 0.8781
# Epoch 37/100
#  - 1s - loss: 0.2770 - accuracy: 0.8789
# Epoch 38/100
#  - 1s - loss: 0.2769 - accuracy: 0.8783
# Epoch 39/100
#  - 1s - loss: 0.2759 - accuracy: 0.8781
# Epoch 40/100
#  - 1s - loss: 0.2765 - accuracy: 0.8778
# Epoch 41/100
#  - 1s - loss: 0.2761 - accuracy: 0.8783
# Epoch 42/100
#  - 1s - loss: 0.2763 - accuracy: 0.8789
# Epoch 43/100
#  - 1s - loss: 0.2755 - accuracy: 0.8783
# Epoch 44/100
#  - 1s - loss: 0.2757 - accuracy: 0.8802
# Epoch 45/100
#  - 1s - loss: 0.2749 - accuracy: 0.8785
# Epoch 46/100
#  - 1s - loss: 0.2745 - accuracy: 0.8791
# Epoch 47/100
#  - 1s - loss: 0.2744 - accuracy: 0.8781
# Epoch 48/100
#  - 1s - loss: 0.2749 - accuracy: 0.8778
# Epoch 49/100
#  - 1s - loss: 0.2746 - accuracy: 0.8790
# Epoch 50/100
#  - 1s - loss: 0.2750 - accuracy: 0.8786
# Epoch 51/100
#  - 1s - loss: 0.2748 - accuracy: 0.8792
# Epoch 52/100
#  - 1s - loss: 0.2743 - accuracy: 0.8798
# Epoch 53/100
#  - 1s - loss: 0.2738 - accuracy: 0.8798
# Epoch 54/100
#  - 1s - loss: 0.2736 - accuracy: 0.8801
# Epoch 55/100
#  - 1s - loss: 0.2741 - accuracy: 0.8783
# Epoch 56/100
#  - 1s - loss: 0.2736 - accuracy: 0.8801
# Epoch 57/100
#  - 1s - loss: 0.2733 - accuracy: 0.8790
# Epoch 58/100
#  - 1s - loss: 0.2725 - accuracy: 0.8817
# Epoch 59/100
#  - 1s - loss: 0.2730 - accuracy: 0.8788
# Epoch 60/100
#  - 1s - loss: 0.2724 - accuracy: 0.8795
# Epoch 61/100
#  - 1s - loss: 0.2726 - accuracy: 0.8786
# Epoch 62/100
#  - 1s - loss: 0.2724 - accuracy: 0.8801
# Epoch 63/100
#  - 1s - loss: 0.2727 - accuracy: 0.8809
# Epoch 64/100
#  - 1s - loss: 0.2730 - accuracy: 0.8799
# Epoch 65/100
#  - 1s - loss: 0.2713 - accuracy: 0.8810
# Epoch 66/100
#  - 1s - loss: 0.2712 - accuracy: 0.8803
# Epoch 67/100
#  - 1s - loss: 0.2716 - accuracy: 0.8813
# Epoch 68/100
#  - 1s - loss: 0.2719 - accuracy: 0.8807
# Epoch 69/100
#  - 1s - loss: 0.2715 - accuracy: 0.8798
# Epoch 70/100
#  - 1s - loss: 0.2717 - accuracy: 0.8784
# Epoch 71/100
#  - 1s - loss: 0.2717 - accuracy: 0.8801
# Epoch 72/100
#  - 1s - loss: 0.2710 - accuracy: 0.8795
# Epoch 73/100
#  - 1s - loss: 0.2720 - accuracy: 0.8786
# Epoch 74/100
#  - 1s - loss: 0.2701 - accuracy: 0.8800
# Epoch 75/100
#  - 1s - loss: 0.2701 - accuracy: 0.8802
# Epoch 76/100
#  - 1s - loss: 0.2712 - accuracy: 0.8798
# Epoch 77/100
#  - 1s - loss: 0.2704 - accuracy: 0.8812
# Epoch 78/100
#  - 1s - loss: 0.2706 - accuracy: 0.8796
# Epoch 79/100
#  - 1s - loss: 0.2699 - accuracy: 0.8806
# Epoch 80/100
#  - 1s - loss: 0.2690 - accuracy: 0.8805
# Epoch 81/100
#  - 1s - loss: 0.2692 - accuracy: 0.8805
# Epoch 82/100
#  - 1s - loss: 0.2680 - accuracy: 0.8821
# Epoch 83/100
#  - 1s - loss: 0.2691 - accuracy: 0.8795
# Epoch 84/100
#  - 1s - loss: 0.2691 - accuracy: 0.8804
# Epoch 85/100
#  - 1s - loss: 0.2694 - accuracy: 0.8797
# Epoch 86/100
#  - 1s - loss: 0.2682 - accuracy: 0.8812
# Epoch 87/100
#  - 1s - loss: 0.2687 - accuracy: 0.8808
# Epoch 88/100
#  - 1s - loss: 0.2676 - accuracy: 0.8812
# Epoch 89/100
#  - 1s - loss: 0.2685 - accuracy: 0.8800
# Epoch 90/100
#  - 1s - loss: 0.2678 - accuracy: 0.8794
# Epoch 91/100
#  - 1s - loss: 0.2680 - accuracy: 0.8819
# Epoch 92/100
#  - 1s - loss: 0.2690 - accuracy: 0.8818
# Epoch 93/100
#  - 1s - loss: 0.2667 - accuracy: 0.8834
# Epoch 94/100
#  - 1s - loss: 0.2667 - accuracy: 0.8822
# Epoch 95/100
#  - 1s - loss: 0.2677 - accuracy: 0.8806
# Epoch 96/100
#  - 1s - loss: 0.2671 - accuracy: 0.8810
# Epoch 97/100
#  - 1s - loss: 0.2674 - accuracy: 0.8794
# Epoch 98/100
#  - 1s - loss: 0.2660 - accuracy: 0.8818
# Epoch 99/100
#  - 1s - loss: 0.2659 - accuracy: 0.8821
# Epoch 100/100
#  - 1s - loss: 0.2662 - accuracy: 0.8805

# %% [markdown]
# # Load the separate test data set

# %%
test_data_df = pd.read_csv("DataWrangling/testing_scaled.csv")
X_test = test_data_df.drop(['Xpert2Outcome_num', 'IF2', 'JF1', 'CAD4TB6'], axis=1).values
Y_test = test_data_df[['Xpert2Outcome_num']].values

test_error_rate = model.evaluate(X_test, Y_test, verbose=0)
print("The mean squared error (MSE) for the test data set is: {}".format(test_error_rate))

# Save the model to disk. It will save both the structure of the neural network but also the trained weights that  determined how the NN works.
model.save("Results/trained_model.h5") #hdf5 it is designed to store python array data.
print("Model saved to disk.")
# Out:
# The mean squared error (MSE) for the test data set is: [0.31367626332842113, 0.8673880696296692]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-5793c2561879> in <module>
#       7
#       8 predictions = model.predict(X_test)
# ----> 9 print(accuracy_score(Y_test, predictions))
#      10 print(confusion_matrix(Y_test, predictions))
#      11 print(classification_report(Y_test, predictions))
#
# ~\.conda\envs\RecSys\lib\site-packages\sklearn\metrics\_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     183
#     184     # Compute accuracy for each possible representation
# --> 185     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     186     check_consistent_length(y_true, y_pred, sample_weight)
#     187     if y_type.startswith('multilabel'):
#
# ~\.conda\envs\RecSys\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      88     if len(y_type) > 1:
#      89         raise ValueError("Classification metrics can't handle a mix of {0} "
# ---> 90                          "and {1} targets".format(type_true, type_pred))
#      91
#      92     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Classification metrics can't handle a mix of binary and continuous targets

# %%
# summarize the first 5 cases
for i in range(5):
	print('%s => %d (expected %d)' % (X[i].tolist(), predictions[i], y[i]))

# %% [markdown]
# # Make Prediction

# %%
X = pd.read_csv().values
prediction = model.predict(X)
prediction = prediction[0][0]

#  total_earnings values were scaled by multiplying by 1.0398469453 and adding -0.021729
prediction = (prediction + 0.021729)/1.0398469453
