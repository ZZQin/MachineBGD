# %%
# first neural network with keras make predictions
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense

import pandas as pd
from pandas.plotting import scatter_matrix
from matplotlib import pyplot as plt

from keras.layers import *

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_absolute_error

from sklearn import model_selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# load the dataset
dataset = pd.read_csv('DataWrangling/ML.csv', index_col=0, na_values=[' ']).fillna(0)

dataset['Xpert2Outcome_num'] = dataset['Xpert2Outcome_num'].astype('int')
dataset.dtypes

# Convert object to 0 and 1
cols = ['Cough', 'Fever', 'Active.Breathing.Shortness', 'Weight.Loss', 'Haemoptysis', 'TB.Medication.History']
dataset[cols] = dataset[cols].replace({'Yes':1, 'No': 0})

# Convert Female to -, male to 1
dataset['Gender'] = dataset['Gender'].replace({'F': '0', 'M': '1'})

array = dataset.values

# split into train_features and train_labels variables
train_features  = array[:,0:9]
train_labels = array[:,12]

# %%
# define the keras model
model = Sequential()
model.add(Dense(9, input_dim=9, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# fit the keras model on the dataset

model.fit(train_features , train_labels, epochs=100, batch_size=10, verbose=2)
# Out:
# Epoch 1/100
#  - 3s - loss: 0.3833 - accuracy: 0.8504
# Epoch 2/100
#  - 3s - loss: 0.3096 - accuracy: 0.8608
# Epoch 3/100
#  - 3s - loss: 0.3029 - accuracy: 0.8684
# Epoch 4/100
#  - 3s - loss: 0.3014 - accuracy: 0.8678
# Epoch 5/100
#  - 3s - loss: 0.2985 - accuracy: 0.8685
# Epoch 6/100
#  - 3s - loss: 0.2962 - accuracy: 0.8683
# Epoch 7/100
#  - 3s - loss: 0.2965 - accuracy: 0.8692
# Epoch 8/100
#  - 3s - loss: 0.2950 - accuracy: 0.8711
# Epoch 9/100
#  - 3s - loss: 0.2944 - accuracy: 0.8695
# Epoch 10/100
#  - 3s - loss: 0.2940 - accuracy: 0.8694
# Epoch 11/100
#  - 3s - loss: 0.2928 - accuracy: 0.8699
# Epoch 12/100
#  - 3s - loss: 0.2942 - accuracy: 0.8704
# Epoch 13/100
#  - 3s - loss: 0.2936 - accuracy: 0.8695
# Epoch 14/100
#  - 3s - loss: 0.2915 - accuracy: 0.8715
# Epoch 15/100
#  - 3s - loss: 0.2926 - accuracy: 0.8720
# Epoch 16/100
#  - 3s - loss: 0.2910 - accuracy: 0.8718
# Epoch 17/100
#  - 3s - loss: 0.2916 - accuracy: 0.8738
# Epoch 18/100
# ...

# %%
# make class predictions with the model
train_predictions = model.predict(train_predictions).ravel()

# summarize the first 10 cases
for i in range(10):
	print('%s => %d (expected %d)' % (train_features [i].tolist(), train_predictions[i], train_labels[i]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-ac78c0575a07> in <module>
#       1 # make class predictions with the model
# ----> 2 train_predictions = model.predict(train_predictions).ravel()
#       3
#       4 # summarize the first 10 cases
#       5 for i in range(10):
#
# NameError: name 'train_predictions' is not defined

# %% [markdown]
# ## Using the test set

# %%
train_predictions = model.predict(train_features).ravel()

# %%
def plot_roc(name, labels, predictions, **kwargs):
  fp, tp, _ = sklearn.metrics.roc_curve(labels, predictions)

  plt.plot(100*fp, 100*tp, label=name, linewidth=2, **kwargs)
  plt.xlabel('False positives [%]')
  plt.ylabel('True positives [%]')
  plt.xlim([-0.5,20])
  plt.ylim([80,100.5])
  plt.grid(True)
  ax = plt.gca()
  ax.set_aspect('equal')


plot_roc("Train Baseline", train_labels, train_predictions)
plt.legend(loc='lower right')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-5af12d1ebc26> in <module>
#      12
#      13
# ---> 14 plot_roc("Train Baseline", train_labels, train_predictions)
#      15 plt.legend(loc='lower right')
#
# <ipython-input-18-5af12d1ebc26> in plot_roc(name, labels, predictions, **kwargs)
#       1 def plot_roc(name, labels, predictions, **kwargs):
# ----> 2   fp, tp, _ = sklearn.metrics.roc_curve(labels, predictions)
#       3
#       4   plt.plot(100*fp, 100*tp, label=name, linewidth=2, **kwargs)
#       5   plt.xlabel('False positives [%]')
#
# NameError: name 'sklearn' is not defined
